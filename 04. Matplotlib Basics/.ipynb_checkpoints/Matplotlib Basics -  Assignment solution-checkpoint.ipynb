# %% [markdown]
# # Matplotlib Basic Assignment solution

# %% [markdown]
# ### Workshop 19.03.2019

# %% [markdown]
# Go through the exercises and solve the tasks.

# %% [markdown]
# #### Example exercise

# %% [markdown]
# Import matplotlib as plt and set the "%matplotlib inline" function in order to se the output in the notebook without using the plt.show() function.

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
'''Test to see if everything works'''
import numpy as np

x = np.arange(0,100)
y = x**2


plt.plot(x,y,'r')
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# <h3 align="center">Exercise 1</h3>

# %% [markdown]
# Plot the function f(x) = 2x + 8 for x=[0,100]
#
# ** Remember to set axis labels and Titles

# %%
# Write code here..

y = 2*x + 8

plt.plot(x,y)

plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Title')

plt.show()

# %% [markdown]
# ___

# %% [markdown]
# <h3 align="center">Exercise 2</h3>

# %% [markdown]
# Plot the two functions f(x) = 2x + 8, and g(x) = 3x - 6 with x beeing at the interval x =[0,100]
#
# ** Important to add labels for the two functions

# %%
# Write code here..

g = 3*x-6

plt.plot(x,y, 'r')
plt.plot(x,g, 'blue')

plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Title')
# Out:
# Text(0.5,1,'Title')

# %% [markdown]
# ___

# %% [markdown]
# <h3 align="center">Exercise 3</h3>

# %% [markdown]
# Plot f(x) in one plot and g(x) in another plot right next to it.
#
# ** Experiment with the thicknes of the plots

# %%
# Write code here..
plt.figure(figsize=(20,5))

# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,2,1)
plt.plot(x, y, 'r--') # More on color options later

plt.subplot(1,2,2)
plt.plot(x, g, 'g-');

# %% [markdown]
# ___

# %% [markdown]
# <h3 align="center">Exercise 4</h3>

# %% [markdown]
# #### Excerise 4

# %% [markdown]
# Plot how the BMI varies on a person with a height of 1.75 meter
#
# **Formula: **
# \begin{align}
# BMI & = \frac{weight[kg]}{height[m]^2}
# \end{align}

# %%
# Write code here..

# BMI(weight,height=constant) --> BMI(weight) = weight / 1.75**2

bmi = x/1.75**2

plt.plot(x,bmi)

plt.xlabel('Weight')
plt.ylabel('BMI(weight)')
plt.title('Linear relation of bmi and weight')

plt.show()

# %% [markdown]
# ___

# %% [markdown]
# <h3 align="center">Exercise 5</h3>

# %% [markdown]
# #### Excerise 5 - Examples of other types of plot

# %% [markdown]
# Make a historgram plot of the ages represented in the dataset

# %%
# Run this code first

import pandas as pd

df = pd.read_csv('physical_health_dataset.csv')

# %%
# Write your code here..

plt.hist(df['Age'], bins= 20)

plt.show()

# %% [markdown]
# ___

# %% [markdown]
# # Well done!
